# %%
#######################################################################################################################
# [PROBLEM STATEMENT]
# We have a dataset for the fire department of New York City.
# Analyze the dataset using pandas to determine:
#
# 1) The total number of fire department facilities in New York City
# 2) The number of fire department facilities in each borough
# 3) The names of facilities in Manhattan
#######################################################################################################################
# AUTHOR  : Aditya Saxena
# DATE    : August 28, 2022
# VERSION : 1.0
#######################################################################################################################

# %%
# [IMPORTING THE REQUIRED LIBRARIES]
import pandas as pd
import numpy  as nu

# %%
# [READ THE DATA FROM THE CSV FILE FOR FIRE DEPARTMENT OF NEW YORK]
df_fdny_csv_data_raw = pd.read_csv('//Users//adityasaxena//Desktop//MyProjects//Data_Science_with_Python//Introduction to Pandas//fdny-firehouse-listing.csv')

# %%
# [DISPLAYING THE DATA]
df_fdny_csv_data_raw
# Out:
#                                           FacilityName  \
# 0                                   Engine 4/Ladder 15
# 1                                  Engine 10/Ladder 10
# 2                                             Engine 6
# 3    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                             Ladder 8
# ..                                                 ...
# 213                  Engine 162/Ladder 82/Battalion 23
# 214                               Engine 167/Ladder 87
# 215                               Engine 164/Ladder 84
# 216                          Engine 168/EMS Station 23
# 217                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough  Postcode   Latitude  Longitude  \
# 0             42 South Street      Manhattan   10005.0  40.703466 -74.007538
# 1          124 Liberty Street      Manhattan   10006.0  40.710072 -74.012523
# ...

# %%
# [VIEW CONTENT OF THE DATA]
df_fdny_csv_data_raw.describe()
# Out:
#            Postcode    Latitude   Longitude  Community Board  \
# count    213.000000  213.000000  213.000000       213.000000
# mean   10783.774648   40.719125  -73.937440         7.075117
# std      556.522394    0.083674    0.093686         7.033880
# min    10001.000000   40.512518  -74.238822         1.000000
# 25%    10304.000000   40.663404  -73.987182         3.000000
# 50%    11103.000000   40.715147  -73.938066         6.000000
# 75%    11231.000000   40.774505  -73.886796        11.000000
# max    11695.000000   40.892803  -73.716559        84.000000
#
#        Community Council    Census Tract           BIN           BBL
# count          213.000000     213.000000  2.130000e+02  2.130000e+02
# mean            25.629108    5949.535211  2.900421e+06  2.849843e+09
# std             15.648512   19571.786111  1.306104e+06  1.285511e+09
# min              1.000000       1.000000  1.000867e+06  1.000350e+09
# 25%             12.000000     129.000000  2.003268e+06  2.025140e+09
# ...

# %%
# [VIEW CONTENT OF THE DATA] - Dirty Method - Do not use
df_fdny_csv_data.describe
# Out:
# <bound method NDFrame.describe of                                     Engine 4/Ladder 15  \
# 0                                  Engine 10/Ladder 10
# 1                                             Engine 6
# 2    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 3                                             Ladder 8
# 4                                    Engine 9/Ladder 6
# ..                                                 ...
# 212                  Engine 162/Ladder 82/Battalion 23
# 213                               Engine 167/Ladder 87
# 214                               Engine 164/Ladder 84
# 215                          Engine 168/EMS Station 23
# 216                               Engine 151/Ladder 76
#
#               42 South Street      Manhattan    10005  40.703466  -74.007538  \
# 0          124 Liberty Street      Manhattan  10006.0  40.710072  -74.012523
# 1           49 Beekman Street      Manhattan  10038.0  40.710048  -74.005245
# ...

# %%
# [VIEW FIRST SIX RECORDS]
df_fdny_csv_data_raw.head(6)
# Out:
#                                         FacilityName        FacilityAddress  \
# 0                                 Engine 4/Ladder 15        42 South Street
# 1                                Engine 10/Ladder 10     124 Liberty Street
# 2                                           Engine 6      49 Beekman Street
# 3  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...   100-104 Duane Street
# 4                                           Ladder 8  14 North Moore Street
# 5                                  Engine 9/Ladder 6        75 Canal Street
#
#      Borough  Postcode   Latitude  Longitude  Community Board  \
# 0  Manhattan   10005.0  40.703466 -74.007538              1.0
# 1  Manhattan   10006.0  40.710072 -74.012523              1.0
# 2  Manhattan   10038.0  40.710048 -74.005245              1.0
# 3  Manhattan   10007.0  40.715463 -74.005938              1.0
# 4  Manhattan   10013.0  40.719759 -74.006678              1.0
# ...

# %%
# [SKIP THE FIRST ROW FROM DATASET]
df_fdny_csv_data = pd.read_csv('//Users//adityasaxena//Desktop//MyProjects//Data_Science_with_Python//Introduction to Pandas//fdny-firehouse-listing.csv', skiprows=1)

# %%
# [VIEW FIRST FIVE RECORDS FROM FIXED DATASET]
df_fdny_csv_data.head(5)
# Out:
#                                   Engine 4/Ladder 15        42 South Street  \
# 0                                Engine 10/Ladder 10     124 Liberty Street
# 1                                           Engine 6      49 Beekman Street
# 2  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...   100-104 Duane Street
# 3                                           Ladder 8  14 North Moore Street
# 4                                  Engine 9/Ladder 6        75 Canal Street
#
#    Manhattan    10005  40.703466  -74.007538    1  1.1       7    1000867  \
# 0  Manhattan  10006.0  40.710072  -74.012523  1.0  1.0    13.0  1075700.0
# 1  Manhattan  10038.0  40.710048  -74.005245  1.0  1.0  1501.0  1001287.0
# 2  Manhattan  10007.0  40.715463  -74.005938  1.0  1.0    33.0  1001647.0
# 3  Manhattan  10013.0  40.719759  -74.006678  1.0  1.0    33.0  1002150.0
# 4  Manhattan  10002.0  40.715213  -73.992901  3.0  1.0    16.0  1003898.0
#
#      1000350001  \
# 0  1.000520e+09
# 1  1.000930e+09
# ...

# %%
# [VIEW DATA STATISTICS USING describe()]
df_fdny_csv_data.describe()
# Out:
#               10005   40.703466  -74.007538           1         1.1  \
# count    212.000000  212.000000  212.000000  212.000000  212.000000
# mean   10787.448113   40.719199  -73.937110    7.103774   25.745283
# std      555.245091    0.083865    0.093783    7.038054   15.593206
# min    10001.000000   40.512518  -74.238822    1.000000    1.000000
# 25%    10304.750000   40.662772  -73.985260    3.000000   12.750000
# 50%    11104.000000   40.715180  -73.937451    6.000000   27.000000
# 75%    11231.000000   40.775525  -73.886782   11.000000   38.000000
# max    11695.000000   40.892803  -73.716559   84.000000   51.000000
#
#                    7       1000867    1000350001
# count     212.000000  2.120000e+02  2.120000e+02
# mean     5977.566038  2.909382e+06  2.858567e+09
# std     19613.823802  1.302617e+06  1.282217e+09
# min         1.000000  1.001287e+06  1.000520e+09
# 25%       129.750000  2.004379e+06  2.026258e+09
# 50%       276.000000  3.066342e+06  3.025125e+09
# ...

# %%
# [VIEW COLUMNS OF DATASET]
df_fdny_csv_data.columns
# Out:
# Index(['Engine 4/Ladder 15', '42 South Street', 'Manhattan', '10005',
#        '40.703466', '-74.007538', '1', '1.1', '7', '1000867', '1000350001',
#        'Battery Park City-Lower Manhattan                                          '],
#       dtype='object')

# %%
# [VIEW INDEX OF DATASET]
df_fdny_csv_data.index
# Out:
# RangeIndex(start=0, stop=217, step=1)

# %%
# [COUNT NUMBER OF RECORDS]
df_fdny_csv_data.count()
# Out:
# Engine 4/Ladder 15                                                             217
# 42 South Street                                                                217
# Manhattan                                                                      217
# 10005                                                                          212
# 40.703466                                                                      212
# -74.007538                                                                     212
# 1                                                                              212
# 1.1                                                                            212
# 7                                                                              212
# 1000867                                                                        212
# 1000350001                                                                     212
# ...

# %%
# [COUNT NUMBER OF RECORDS] - DIRTY METHOD - do not use
df_fdny_csv_data.count
# Out:
# <bound method DataFrame.count of                                     Engine 4/Ladder 15  \
# 0                                  Engine 10/Ladder 10
# 1                                             Engine 6
# 2    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 3                                             Ladder 8
# 4                                    Engine 9/Ladder 6
# ..                                                 ...
# 212                  Engine 162/Ladder 82/Battalion 23
# 213                               Engine 167/Ladder 87
# 214                               Engine 164/Ladder 84
# 215                          Engine 168/EMS Station 23
# 216                               Engine 151/Ladder 76
#
#               42 South Street      Manhattan    10005  40.703466  -74.007538  \
# 0          124 Liberty Street      Manhattan  10006.0  40.710072  -74.012523
# 1           49 Beekman Street      Manhattan  10038.0  40.710048  -74.005245
# ...

# %%
# [VIEW DATATYPES]
df_fdny_csv_data.dtypes
# Out:
# Engine 4/Ladder 15                                                              object
# 42 South Street                                                                 object
# Manhattan                                                                       object
# 10005                                                                          float64
# 40.703466                                                                      float64
# -74.007538                                                                     float64
# 1                                                                              float64
# 1.1                                                                            float64
# 7                                                                              float64
# 1000867                                                                        float64
# 1000350001                                                                     float64
# ...

# %%
# [DISPLAY FDNY INFORMATION]
df_fdny_csv_data
# Out:
#                                     Engine 4/Ladder 15  \
# 0                                  Engine 10/Ladder 10
# 1                                             Engine 6
# 2    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 3                                             Ladder 8
# 4                                    Engine 9/Ladder 6
# ..                                                 ...
# 212                  Engine 162/Ladder 82/Battalion 23
# 213                               Engine 167/Ladder 87
# 214                               Engine 164/Ladder 84
# 215                          Engine 168/EMS Station 23
# 216                               Engine 151/Ladder 76
#
#               42 South Street      Manhattan    10005  40.703466  -74.007538  \
# 0          124 Liberty Street      Manhattan  10006.0  40.710072  -74.012523
# 1           49 Beekman Street      Manhattan  10038.0  40.710048  -74.005245
# ...

# %%
# [THE ABOVE DATAS DOES NOT HAVE THE TERM BOROUGH. HENCE WE WILL HAVE TO GO TO THE RAW DATA]
df_fdny_csv_data_new = pd.read_csv('//Users//adityasaxena//Desktop//MyProjects//Data_Science_with_Python//Introduction to Pandas//fdny-firehouse-listing.csv')

# %%
df_fdny_csv_data_new
# Out:
#                                           FacilityName  \
# 0                                   Engine 4/Ladder 15
# 1                                  Engine 10/Ladder 10
# 2                                             Engine 6
# 3    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                             Ladder 8
# ..                                                 ...
# 213                  Engine 162/Ladder 82/Battalion 23
# 214                               Engine 167/Ladder 87
# 215                               Engine 164/Ladder 84
# 216                          Engine 168/EMS Station 23
# 217                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough  Postcode   Latitude  Longitude  \
# 0             42 South Street      Manhattan   10005.0  40.703466 -74.007538
# 1          124 Liberty Street      Manhattan   10006.0  40.710072 -74.012523
# ...

# %%
# [VIEW FDNY INFORMATION BOROUGHWISE]
groupby_boroughwise = df_fdny_csv_data_new.groupby('Borough')

# %%
# [VIEW FDNY INFORMATION FOR EACH BOROUGH]
groupby_boroughwise.size()
# Out:
# Borough
# Bronx            34
# Brooklyn         66
# Manhattan        48
# Queens           50
# Staten Island    20
# dtype: int64

# %%
# [SELECT FDNY INFORMATION FOR MANHATTAN]
fdny_info_Manhattan = groupby_boroughwise.get_group('Manhattan')

# %%
# [VIEW FDNY INFORMATION FOR MANHATTAN]
fdny_info_Manhattan
# Out:
#                                          FacilityName  \
# 0                                  Engine 4/Ladder 15
# 1                                 Engine 10/Ladder 10
# 2                                            Engine 6
# 3   Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                            Ladder 8
# 5                                   Engine 9/Ladder 6
# 6                     Engine 15/Ladder 18/Battalion 4
# 7                                 Engine 28/Ladder 11
# 8                                            Engine 5
# 9                                           Engine 55
# 10                               Ladder 20/Division 1
# 11                     Engine 24/Ladder 5/Battalion 2
# 12                                 Engine 33/Ladder 9
# 13                               Ladder 3/Battalion 6
# 14                                           Squad 18
# 15                                Engine 34/Ladder 21
# ...
